# %%
import pandas as pd
cosine_sim_df = pd.read_csv('../dataset/cosine_sim.csv', delimiter=',', encoding='utf-8')
netflix_df = pd.read_csv('../dataset/netflix_titles.csv', delimiter=',', encoding='utf-8')
cosine_sim_df.head()
# Out:
#    Dick Johnson Is Dead  Blood & Water  Ganglands  Jailbirds New Orleans  \
# 0              1.000000            0.0        0.0                    0.0
# 1              0.000000            1.0        0.0                    0.0
# 2              0.000000            0.0        1.0                    0.0
# 3              0.000000            0.0        0.0                    1.0
# 4              0.015222            0.0        0.0                    0.0
#
#    Kota Factory  Midnight Mass  My Little Pony: A New Generation  Sankofa  \
# 0      0.015222       0.000000                           0.00000      0.0
# 1      0.000000       0.031227                           0.05166      0.0
# 2      0.000000       0.000000                           0.00000      0.0
# 3      0.000000       0.000000                           0.00000      0.0
# 4      1.000000       0.000000                           0.00000      0.0
#
#    The Great British Baking Show  The Starling  ...  Zak Storm  Zed Plus  \
# 0                       0.040165      0.017411  ...   0.000000  0.000000
# 1                       0.000000      0.000000  ...   0.035331  0.032784
# 2                       0.000000      0.000000  ...   0.000000  0.000000
# 3                       0.000000      0.000000  ...   0.000000  0.000000
# 4                       0.000000      0.016718  ...   0.000000  0.000000
#
#       Zenda  Zindagi Gulzar Hai   Zinzana  Zodiac  Zombie Dumb  Zombieland  \
# 0  0.000000                 0.0  0.000000     0.0        0.000    0.000000
# 1  0.116936                 0.0  0.032609     0.0        0.042    0.000000
# 2  0.000000                 0.0  0.000000     0.0        0.000    0.000000
# 3  0.000000                 0.0  0.000000     0.0        0.000    0.000000
# 4  0.000000                 0.0  0.000000     0.0        0.000    0.035196
#
#        Zoom    Zubaan
# 0  0.015383  0.000000
# 1  0.000000  0.000000
# 2  0.000000  0.022301
# 3  0.016386  0.000000
# 4  0.068784  0.000000
#
# [5 rows x 8807 columns]

# %%
def get_recomendation(title, df=netflix_df, cosine_sim=cosine_sim_df, n=10) -> list:
    try:
        sim = list(enumerate(cosine_sim_df.loc[title]))
        sim = sorted(sim, key= lambda x: x[1], reverse=True)[1:11]
        indices = [i[0] for i in sim]
        return df['title'].iloc[indices].to_list()
    except KeyError:
        return 'No so-called film in database'
